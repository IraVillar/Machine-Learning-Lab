# %%
import pandas as pd

# %%
returns = pd.read_csv("Returns.csv")
returns
# Out:
#      Returned                  Order ID             Region
# 0         Yes  CA-2012-SA20830140-41210         Central US
# 1         Yes  IN-2012-PB19210127-41259       Eastern Asia
# 2         Yes  CA-2012-SC20095140-41174         Central US
# 3         Yes    IN-2015-JH158207-42140            Oceania
# 4         Yes    IN-2014-LC168857-41747            Oceania
# 5         Yes   ID-2013-AB1001527-41439       Eastern Asia
# 6         Yes   ES-2015-RA1994545-42218     Western Europe
# 7         Yes  CA-2014-TB21280140-41724         Central US
# 8         Yes  ES-2014-JF15295120-41924    Southern Europe
# 9         Yes   IN-2014-NM1844527-41800       Eastern Asia
# 10        Yes    IN-2015-GB145307-42260            Oceania
# 11        Yes    ES-2012-SC208458-41070     Western Europe
# 12        Yes  TU-2013-SF10200134-41417       Western Asia
# 13        Yes   ID-2015-RD1993092-42140            Oceania
# 14        Yes  CA-2014-TC21295140-41800        Southern US
# ...
